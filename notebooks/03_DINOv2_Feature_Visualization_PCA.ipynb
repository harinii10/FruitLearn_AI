# %% [markdown]
# # FruitLearn AI: DINOv2 Attention Map & PCA Feature Visualization
# **Author:** Harini (Member 1 - DINOv2 Owner & Model Architecture Lead)
#
# Visualizing self-attention maps and PCA components extracted from DINOv2 register tokens showing semantic fruit segmentation without pixel supervision.

# %%
import matplotlib.pyplot as plt
import torch
from src.dinov2_backbone import load_dinov2_pretrained

print("Attention map visualization suite initialized.")
