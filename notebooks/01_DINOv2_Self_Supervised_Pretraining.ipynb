# %% [markdown]
# # FruitLearn AI: DINOv2 Self-Distillation Self-Supervised Pre-Training
# **Author:** Harini (Member 1 - DINOv2 Owner & Model Architecture Lead)
#
# This notebook implements Self-Supervised Learning using DINOv2 (ViT-Base/14) with Teacher-Student Exponential Moving Average (EMA) and Multi-Crop data augmentation.

# %%
import torch
from src.dinov2_backbone import load_dinov2_pretrained
from src.train_dinov2 import DINOLoss

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = load_dinov2_pretrained().to(device)
dino_loss = DINOLoss()
print(f"DINOv2 ViT-Base/14 Engine initialized on: {device}")
